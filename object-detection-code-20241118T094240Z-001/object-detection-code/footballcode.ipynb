# %%
# !pip install unzip

# %%
pip install torch opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -q pyomo
# !apt-get install -y -qq glpk-utils
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !git clone https://github.com/freedomwebtech/yolov5train
# !unzip /content/yolov5train/yolov5.zip -d /content/yolov5train
# %cd /content/yolov5train/yolov5
# !pip3 install -r requirements.txt
# !apt-get install rar!git clone https://github.com/freedomwebtech/yolov5train
# !apt-get install rar
# Out:
# fatal: destination path 'yolov5train' already exists and is not an empty directory.
# [WinError 3] The system cannot find the path specified: '/content/yolov5train/yolov5'
# c:\Users\HP\Desktop\football\object-detection-code-20241118T094240Z-001\object-detection-code
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.
# C:\Users\HP\AppData\Roaming\Python\Python312\site-packages\IPython\core\magics\osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !apt-get install zip
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !unzip /content/drive/MyDrive/detect/detect1.zip  -d /content/drive/MyDrive/detect1
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install wandb

# %%
# !pip install roboflow
# Out:
# ...
#   Using cached roboflow-1.1.49-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# ...
# Using cached roboflow-1.1.49-py3-none-any.whl (80 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="") # THIS API KEY IS REVOKED. PLEASE USE YOUR OWN API KEY
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:01<00:00, 693.25it/s]

# %%
# !python3  --img 400 --batch 10 --epochs 10 --data "C:\Users\HP\Desktop\football\object-detection-code-20241118T094240Z-001\object-detection-code\football-players-detection-1\data.yaml" --weights yolov5l.pt --project 'C:\Users\HP\Desktop\football\object-detection-code-20241118T094240Z-001\object-detection-code\football-players-detection-1\train' --name 'demo_weights'
# Out:
# python3: can't open file 'c:\\content\\yolov5train\\yolov5\\train.py': [Errno 2] No such file or directory

# %%
# !python /content/yolov5train/yolov5/detect.py --weights /content/drive/MyDrive/detect1/detect/train/demo_weights/weights/best.pt --img 640 --conf 0.70 --source /content/drive/MyDrive/video1.mp4
# Out:
# detect: weights=['/content/drive/MyDrive/detect1/detect/train/demo_weights/weights/best.pt'], source=/content/drive/MyDrive/video1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.7, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2022-10-4 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
'!python /content/drive/MyDrive/detect--weights /content/gdrive/MyDrive/find_ob/demo_weights/weights/best.pt --img 640 --conf 0.70 --source /content/images2.jpg
# Out:
# detect: weights=['/content/gdrive/MyDrive/find_ob/demo_weights/weights/best.pt'], source=/content/images2.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.7, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2022-10-4 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python /content/yolov5train/yolov5/detect.py --weights /content/gdrive/MyDrive/find_ob/demo_weights/weights/best.pt --img 640 --conf 0.70 --source !python /content/yolov5train/yolov5/detect.py --weights /content/gdrive/MyDrive/find_ob/demo_weights/weig hts/best.pt --img 640 --conf 0.70 --source /content/download2.jpg
# Out:
# usage: detect.py [-h] [--weights WEIGHTS [WEIGHTS ...]] [--source SOURCE] [--data DATA]
#                  [--imgsz IMGSZ [IMGSZ ...]] [--conf-thres CONF_THRES] [--iou-thres IOU_THRES]
#                  [--max-det MAX_DET] [--device DEVICE] [--view-img] [--save-txt] [--save-conf]
#                  [--save-crop] [--nosave] [--classes CLASSES [CLASSES ...]] [--agnostic-nms]
#                  [--augment] [--visualize] [--update] [--project PROJECT] [--name NAME]
#                  [--exist-ok] [--line-thickness LINE_THICKNESS] [--hide-labels] [--hide-conf]
#                  [--half] [--dnn] [--vid-stride VID_STRIDE]
# detect.py: error: unrecognized arguments: /content/yolov5train/yolov5/detect.py

# %%
OII IRUKU SOURCE ENA PASTE PANNANUM
